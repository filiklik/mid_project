# %%
# load libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
warnings.filterwarnings("ignore", message="numpy.ufunc size changed")
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# Importing the data
credit= pd.read_csv("C:/Users/shili/Desktop/Project_Final/creditcardmarketing.csv")

# %%
##Exploring the data

# %%
credit.dropna(0, 'any', inplace = True)

# %%
credit.reset_index(inplace = True)

# %%
credit.columns = credit.columns.str.lower()
credit.columns = credit.columns.str.replace(' ', '_')
credit.columns
# Out:
# Index(['index', 'customer_number', 'offer_accepted', 'reward', 'mailer_type',
#        'income_level', '#_bank_accounts_open', 'overdraft_protection',
#        'credit_rating', '#_credit_cards_held', '#_homes_owned',
#        'household_size', 'own_your_home', 'average_balance', 'q1_balance',
#        'q2_balance', 'q3_balance', 'q4_balance'],
#       dtype='object')

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17976 entries, 0 to 17975
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   index                 17976 non-null  int64
#  1   customer_number       17976 non-null  int64
#  2   offer_accepted        17976 non-null  object
#  3   reward                17976 non-null  object
#  4   mailer_type           17976 non-null  object
#  5   income_level          17976 non-null  object
#  6   #_bank_accounts_open  17976 non-null  int64
#  7   overdraft_protection  17976 non-null  object
#  8   credit_rating         17976 non-null  object
#  9   #_credit_cards_held   17976 non-null  int64
#  10  #_homes_owned         17976 non-null  int64
#  11  household_size        17976 non-null  int64
#  12  own_your_home         17976 non-null  object
#  13  average_balance       17976 non-null  float64
#  14  q1_balance            17976 non-null  float64
# ...

# %%
credit.isna().sum()
# Out:
# index                   0
# customer_number         0
# offer_accepted          0
# reward                  0
# mailer_type             0
# income_level            0
# #_bank_accounts_open    0
# overdraft_protection    0
# credit_rating           0
# #_credit_cards_held     0
# #_homes_owned           0
# household_size          0
# own_your_home           0
# average_balance         0
# q1_balance              0
# q2_balance              0
# q3_balance              0
# q4_balance              0
# dtype: int64

# %%
credit.head()
# Out:
#   offer_accepted     reward mailer_type income_level  #_bank_accounts_open  \
# 0             No  Air Miles      Letter         High                     1
# 1             No  Air Miles      Letter       Medium                     1
# 2             No  Air Miles    Postcard         High                     2
# 3             No  Air Miles      Letter       Medium                     2
# 4             No  Air Miles      Letter       Medium                     1
#
#   overdraft_protection credit_rating  #_credit_cards_held  #_homes_owned  \
# 0                   No          High                    2              1
# 1                   No        Medium                    2              2
# 2                   No        Medium                    2              1
# 3                   No          High                    1              1
# 4                   No        Medium                    2              1
#
#    household_size own_your_home  average_balance  q1_balance  q2_balance  \
# ...

# %%
 print("Shape of ceredit_data:", credit.shape)
# Out:
# Shape of ceredit_data: (17976, 16)

# %%
credit.describe()
# Out:
#             level_0         index  customer_number  #_bank_accounts_open  \
# count  17976.000000  17976.000000     17976.000000          17976.000000
# mean    8987.500000   8998.727192      8999.727192              1.255730
# std     5189.368555   5196.958865      5196.958865              0.472405
# min        0.000000      0.000000         1.000000              1.000000
# 25%     4493.750000   4497.750000      4498.750000              1.000000
# 50%     8987.500000   8999.500000      9000.500000              1.000000
# 75%    13481.250000  13500.250000     13501.250000              1.000000
# max    17975.000000  17999.000000     18000.000000              3.000000
#
#        #_credit_cards_held  #_homes_owned  household_size  average_balance  \
# count         17976.000000   17976.000000    17976.000000     17976.000000
# mean              1.903427       1.203549        3.499110       940.515562
# std               0.797086       0.427446        1.114476       350.297837
# ...

# %%
credit=credit.drop(columns=['customer_number','index'])

# %%
credit.keys()
# Out:
# Index(['offer_accepted', 'reward', 'mailer_type', 'income_level',
#        '#_bank_accounts_open', 'overdraft_protection', 'credit_rating',
#        '#_credit_cards_held', '#_homes_owned', 'household_size',
#        'own_your_home', 'average_balance', 'q1_balance', 'q2_balance',
#        'q3_balance', 'q4_balance'],
#       dtype='object')

# %%
# assessing  charactersitics of customers to affects their decision to get a card or not

fig, axes = plt.subplots(5, 2, figsize=(15,15))
fig.suptitle('Customer replies')
sns.countplot(ax=axes[0, 0], data=credit, x='offer_accepted', hue='reward')
sns.countplot(ax=axes[0, 1], data=credit, x='offer_accepted', hue='mailer_type')
sns.countplot(ax=axes[1, 0], data=credit, x='offer_accepted', hue='income_level')
sns.countplot(ax=axes[1, 1], data=credit, x='offer_accepted', hue='#_bank_accounts_open')
sns.countplot(ax=axes[2, 0], data=credit, x='offer_accepted', hue='overdraft_protection')
sns.countplot(ax=axes[2, 1], data=credit, x='offer_accepted', hue='credit_rating')
sns.countplot(ax=axes[3, 0], data=credit, x='offer_accepted', hue='#_credit_cards_held')
sns.countplot(ax=axes[3, 1], data=credit, x='offer_accepted', hue='#_homes_owned')
sns.countplot(ax=axes[4, 0], data=credit, x='offer_accepted', hue='household_size')
sns.countplot(ax=axes[4, 1], data=credit, x='offer_accepted', hue='own_your_home')
# Out:
# <AxesSubplot:xlabel='offer_accepted', ylabel='count'>

# %%
#The correlation of the numerical columns.
corr_matrix = credit.corr(method = 'pearson')
fig, ax = plt.subplots(figsize = (10, 8))
ax = sns.heatmap(corr_matrix, annot = True)
plt.show()

# %%
#There is high correlation betwenn q2, q3 balance with average balance.

# %%
# looking at the above charts, there doesn't seem to be any correlation between people chosing to get a credit card and other charactestistics.

# %%
#Here are the summary of the features:
#Discrete Numerical Data:
    #Bank Account Open
    #Credit Card Held
    #Home Owned
#Continous Numercial Data:
    # Balance (Average and for each quarter)
#Categorical Data:
    #Offer Accepted (Target)
    # Reward 
    # Income Level
    # Overdraft Protection 
    # Credit Rating
    #Own your Home

# %%
credit.shape
# Out:
# (17976, 16)

# %%
credit['offer_accepted'].value_counts()
# Out:
# No     16955
# Yes     1021
# Name: offer_accepted, dtype: int64

# %%
credit['income_level'].value_counts()
# Out:
# Medium    9002
# High      4519
# Low       4455
# Name: income_level, dtype: int64

# %%
credit['#_bank_accounts_open'].value_counts()
# Out:
# 1    13674
# 2     4007
# 3      295
# Name: #_bank_accounts_open, dtype: int64

# %%
credit['#_credit_cards_held'].value_counts()
# Out:
# 2    7933
# 1    6147
# 3    3381
# 4     515
# Name: #_credit_cards_held, dtype: int64

# %%
credit['#_homes_owned'].value_counts()
# Out:
# 1    14502
# 2     3289
# 3      185
# Name: #_homes_owned, dtype: int64

# %%
credit['household_size'].value_counts()
# Out:
# 3    5705
# 4    5532
# 5    2851
# 2    2809
# 1     539
# 6     538
# 8       1
# 9       1
# Name: household_size, dtype: int64

# %%
#Distribution of average balance and the Q1, Q2, Q3, and Q4 balances
sns.distplot(credit['average_balance'])
# Out:
# <AxesSubplot:xlabel='average_balance', ylabel='Density'>

# %%
sns.distplot(credit['q1_balance'])
# Out:
# <AxesSubplot:xlabel='q1_balance', ylabel='Density'>

# %%
sns.distplot(credit['q2_balance'])
# Out:
# <AxesSubplot:xlabel='q2_balance', ylabel='Density'>

# %%
sns.distplot(credit['q3_balance'])
# Out:
# <AxesSubplot:xlabel='q3_balance', ylabel='Density'>

# %%
sns.distplot(credit['q4_balance'])
# Out:
# <AxesSubplot:xlabel='q4_balance', ylabel='Density'>

# %%
credit.dtypes
# Out:
# offer_accepted           object
# reward                   object
# mailer_type              object
# income_level             object
# #_bank_accounts_open      int64
# overdraft_protection     object
# credit_rating            object
# #_credit_cards_held       int64
# #_homes_owned             int64
# household_size            int64
# own_your_home            object
# average_balance         float64
# q1_balance              float64
# q2_balance              float64
# q3_balance              float64
# q4_balance              float64
# dtype: object

# %%
##Modeling

# %%
#There is high correlation betwenn q2, q3 balance with average balance. 
#I decided to only keep the average_balance for the first try out: data_avg1

credit_Avg = credit.drop(['q1_balance', 'q2_balance', 'q3_balance', 'q4_balance'], axis =1)

# %%
credit_Avg.head(5)
# Out:
#   offer_accepted     reward mailer_type income_level  #_bank_accounts_open  \
# 0             No  Air Miles      Letter         High                     1
# 1             No  Air Miles      Letter       Medium                     1
# 2             No  Air Miles    Postcard         High                     2
# 3             No  Air Miles      Letter       Medium                     2
# 4             No  Air Miles      Letter       Medium                     1
#
#   overdraft_protection credit_rating  #_credit_cards_held  #_homes_owned  \
# 0                   No          High                    2              1
# 1                   No        Medium                    2              2
# 2                   No        Medium                    2              1
# 3                   No          High                    1              1
# 4                   No        Medium                    2              1
#
#    household_size own_your_home  average_balance
# ...

# %%
##Using histogram to see how the data distribute in all features

for col in credit_Avg.columns:
    sns.displot(data = credit[col], bins = 50)
plt.show()

# %%
# most customer's have a balance under approximately 25,000.

# %%
for col in credit_Avg.columns:
    a = data_avg1[col].value_counts()
    print(a)
# Out:
# No     16955
# Yes     1021
# Name: offer_accepted, dtype: int64
# Air Miles    6047
# Cash Back    5995
# Points       5934
# Name: reward, dtype: int64
# Postcard    9134
# Letter      8842
# Name: mailer_type, dtype: int64
# Medium    9002
# High      4519
# Low       4455
# Name: income_level, dtype: int64
# 1    13674
# 2     4007
# 3      295
# Name: #_bank_accounts_open, dtype: int64
# No     15300
# Yes     2676
# Name: overdraft_protection, dtype: int64
# High      6064
# Medium    5964
# Low       5948
# Name: credit_rating, dtype: int64
# 2    7933
# 1    6147
# 3    3381
# 4     515
# Name: #_credit_cards_held, dtype: int64
# 1    14502
# 2     3289
# 3      185
# Name: #_homes_owned, dtype: int64
# 3    5705
# 4    5532
# 5    2851
# 2    2809
# 1     539
# 6     538
# 8       1
# 9       1
# Name: household_size, dtype: int64
# Yes    11636
# No      6340
# Name: own_your_home, dtype: int64
# 1127.00    17
# 1033.00    16
# 1070.00    16
# 1053.50    16
# 1036.00    16
# ...

# %%
##income_level, credit_rating convert to numerical features, as there is a level increasing in these features

credit_Avg['income_level'].replace({"High":"3", "Medium" : "2", "Low" : "1"}, inplace=True)
credit_Avg['credit_rating'].replace({"High":"3", "Medium" : "2", "Low" : "1"}, inplace=True)

# %%
credit_Avg.head(5)
# Out:
#   offer_accepted     reward mailer_type income_level  #_bank_accounts_open  \
# 0             No  Air Miles      Letter            3                     1
# 1             No  Air Miles      Letter            2                     1
# 2             No  Air Miles    Postcard            3                     2
# 3             No  Air Miles      Letter            2                     2
# 4             No  Air Miles      Letter            2                     1
#
#   overdraft_protection credit_rating  #_credit_cards_held  #_homes_owned  \
# 0                   No             3                    2              1
# 1                   No             2                    2              2
# 2                   No             2                    2              1
# 3                   No             3                    1              1
# 4                   No             2                    2              1
#
#    household_size own_your_home  average_balance
# ...

# %%
## Modeling

# %%
#Encoding categorical data
credit_Avg_m1 = pd.get_dummies(data_avg1, columns = ['offer_accepted','reward', 'mailer_type', 'overdraft_protection', 'own_your_home'], drop_first = True)

# %%
##Converting data type
credit_Avg_m1['income_level'] = data_avg_m1['income_level'].astype('int')
credit_Avg_m1['credit_rating'] = data_avg_m1['credit_rating'].astype('int')

# %%
credit_Avg_m1.head(5)
# Out:
#    income_level  #_bank_accounts_open  credit_rating  #_credit_cards_held  \
# 0             3                     1              3                    2
# 1             2                     1              2                    2
# 2             3                     2              2                    2
# 3             2                     2              3                    1
# 4             2                     1              2                    2
#
#    #_homes_owned  household_size  average_balance  offer_accepted_Yes  \
# 0              1               4          1160.75                   0
# 1              2               5           147.25                   0
# 2              1               2           276.50                   0
# 3              1               4          1219.00                   0
# 4              1               6          1211.00                   0
#
#    reward_Cash Back  reward_Points  mailer_type_Postcard  \
# ...

# %%
X = credit_Avg_m1.drop(['offer_accepted_Yes'], axis =1)
y = credit_Avg_m1['offer_accepted_Yes']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=100)

# %%
#Linear Regression model

from sklearn import linear_model
lm = linear_model.LinearRegression()
model1 = lm.fit(X_train, y_train)
score = lm.score(X_test,y_test)
score
# Out:
# 0.044779978444245416

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

X = sm.add_constant(X)
model1 = sm.OLS(y,X).fit()
print(model1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:     offer_accepted_Yes   R-squared:                       0.045
# Model:                            OLS   Adj. R-squared:                  0.044
# Method:                 Least Squares   F-statistic:                     70.39
# Date:                Sun, 27 Feb 2022   Prob (F-statistic):          5.35e-169
# Time:                        21:45:00   Log-Likelihood:                 1211.6
# No. Observations:               17976   AIC:                            -2397.
# Df Residuals:                   17963   BIC:                            -2296.
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        0.2070      0.013     16.159      0.000       0.182       0.232
# ...

# %%
#KNN model

from sklearn.neighbors import KNeighborsRegressor, KNeighborsClassifier

KNN = KNeighborsRegressor(n_neighbors=6, weights = 'distance')
KNN.fit(X_train, y_train)
score = KNN.score(X_test, y_test)
score
# Out:
# -0.13081629654058435

# %%
#Logistic model

from sklearn.linear_model import LogisticRegression
classification = LogisticRegression(random_state=0, solver='lbfgs',
                  multi_class='multinomial').fit(X_train, y_train)

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, plot_confusion_matrix

#check the predict data

Y_train_perditct = classification.predict(X_train)
Y_test_perditct = classification.predict(X_test)

# %%
#to see the accurracy

plot_confusion_matrix(classification,X_train, y_train)
plot_confusion_matrix(classification,X_test, y_test)

##As you can see, this model is only able to predict "no".

# %%
classification.score(X_test, y_test)
# Out:
# 0.9436795994993742

# %%
corr_matrix = data_avg_m1.corr(method = 'pearson')
fig, ax = plt.subplots(figsize = (15, 13))
ax = sns.heatmap(corr_matrix, annot = True)
plt.show()
